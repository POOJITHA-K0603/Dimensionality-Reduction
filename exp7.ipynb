# %% [markdown]
# Before running the PCA code, please upload your `student_pca_dataset.csv` file.

# %%
from google.colab import files
import io

uploaded = files.upload()

# Assuming the user uploads 'student_pca_dataset.csv'
# If the uploaded file has a different name, you'll need to adjust the pd.read_csv call.
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-5553a054-373e-4bbd-b501-c78d3c2687b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5553a054-373e-4bbd-b501-c78d3c2687b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Experiment 7: Dimensionality Reduction using PCA
# Dataset: Student PCA Dataset

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load dataset
data = pd.read_csv("student_pca_dataset.csv")

# Display dataset
print("Dataset:")
print(data)

# Select features
X = data[[
    "Math_Score",
    "Science_Score",
    "English_Score",
    "Computer_Score"
]]

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Display shapes
print("\nOriginal Shape:", X.shape)
print("Reduced Shape :", X_pca.shape)

# Display explained variance
print("\nExplained Variance Ratio:")
print(pca.explained_variance_ratio_)

# Display transformed data
print("\nPCA Transformed Data:")
print(X_pca)

# Plot PCA result
plt.scatter(X_pca[:, 0], X_pca[:, 1], s=100)

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA on Student Score Dataset")

plt.show()
# Out:
# Dataset:
#     Math_Score  Science_Score  English_Score  Computer_Score
# 0           78             82             75              88
# 1           65             70             68              72
# 2           88             90             85              92
# 3           55             60             58              65
# 4           72             75             70              78
# 5           91             94             89              96
# 6           60             64             62              68
# 7           83             86             80              90
# 8           69             73             72              75
# 9           95             96             93              98
# 10          58             62             60              64
# 11          76             79             74              82
# 12          84             88             83              91
# 13          63             68             65              70
# ...
